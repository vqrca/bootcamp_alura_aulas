# %% [markdown]
# #**O que aprendemos nessa aula:**
#
# Como usar o Groupby;
#
# Como alterar a Palete de cores do seu gráfico com seaborn;
#
# Como usar a Palete de cores para ajudar na interpretação dos gráficos;
#
# O que é e como usar o catplot para comparar categorias.

# %% [markdown]
# ##**Importando as bibliotecas**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns

# %% [markdown]
# ##**Importando os dados**

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/vqrca/bootcamp_alura_aulas/main/Modulo_2/gastos_totais_ano_mes_atendimento.csv', encoding='ISO-8859-1', 
                    skiprows = 3, sep=';', skipfooter=12, thousands='.', decimal=',')
dados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   Unidade da Federação 1992/Mar  ...     2021/Mar         Total
# 0          11 Rondônia        -  ...   4732441.04  9.964113e+08
# 1              12 Acre        -  ...   1137341.65  4.500485e+08
# 2          13 Amazonas        -  ...   6799060.80  1.917248e+09
# 3           14 Roraima        -  ...   2381844.31  3.288770e+08
# 4              15 Pará        -  ...  13069564.31  4.705309e+09
#
# [5 rows x 287 columns]

# %%
pd.options.display.float_format = "{:.2f}".format #tirando notação científica

# %%
#Checando quais são as colunas usáveis:
dados.mean().index
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov', '2020/Dez',
#        '2021/Jan', '2021/Fev', '2021/Mar', 'Total'],
#       dtype='object', length=165)

# %%
#Guardando as colunas usáveis numa variável:
colunas_usaveis = dados.mean().index
colunas_usaveis
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov', '2020/Dez',
#        '2021/Jan', '2021/Fev', '2021/Mar', 'Total'],
#       dtype='object', length=165)

# %%
dados[colunas_usaveis]
# Out:
#      2007/Ago   2007/Set    2007/Out  ...     2021/Fev     2021/Mar          Total
# 0     4209.37   16397.03   133645.19  ...   6039419.59   4732441.04   996411254.68
# 1    10470.07   14001.71    86200.85  ...   2272733.90   1137341.65   450048530.47
# 2    35752.72   45570.64   416012.30  ...  13679358.06   6799060.80  1917247936.05
# 3     4785.91   11858.63    43852.67  ...   3044798.77   2381844.31   328876965.09
# 4   181159.29  433414.74  1893197.50  ...  23343222.94  13069564.31  4705309002.29
# 5    33672.74  104822.98   118378.28  ...   1534733.18    989155.40   309860092.59
# 6     4113.76   76633.06   343702.61  ...    416534.32    928756.84  1020028272.64
# 7   385330.18 1018352.93  2277717.78  ...  23260245.95  17294509.11  3871069498.04
# 8   220788.25  353468.67  1078182.68  ...  13636005.36   9542151.53  2280888802.74
# 9   357904.65  572356.18  1865065.71  ...  30186951.00  17173151.55  6591836650.18
# 10  134605.36  272088.08   684678.30  ...  18186942.80   8733455.36  2660122027.15
# 11   97352.78  368130.43  1002088.64  ...  16996494.03  12517894.05  2614919044.63
# 12  400640.85 1088340.42  2973553.48  ...  62259409.32  39472738.81  8581189975.91
# 13  104243.75  174024.90   595544.54  ...  12792571.64   8180887.21  2236415402.51
# 14   27453.63   78565.19   122952.94  ...   4129845.36   3081081.42  1215853015.00
# 15  135146.36  448349.75  1382038.11  ...  55544579.04  31314602.44  9791541570.52
# 16  971394.37 2861781.50 10018011.35  ... 119877417.15  79780838.00 20418737536.66
# 17   57408.11  284224.80  1152115.25  ...  25669612.63  15606368.11  3405850698.58
# 18  469469.34  921646.57  2994664.57  ...  60873103.08  49149884.48 10337389922.09
# 19 1665349.90 4434168.64 14577395.84  ... 268193064.06 177408317.71 41396408548.81
# 20  554800.22 1431708.01  4630402.44  ...  83130175.37  43480729.07 14681514706.67
# 21  693955.05 1092964.12  3562300.82  ...  47429335.91  19375822.56  7835011163.40
# 22 1049252.33 3182913.14  8571312.11  ...  84404640.00  37798832.80 12764391179.92
# 23  199556.12  573675.41  1069816.66  ...  11428462.42   4035989.77  2324525096.33
# 24   63562.50  232444.62   927219.59  ...  13207979.82   8835890.09  2180119781.15
# 25  179395.82  418053.58  1198730.25  ...  32253788.65  24867001.02  4973572261.43
# 26  191951.47  769966.25  2165619.56  ...  19004029.87  14731938.43  2592422853.56
#
# [27 rows x 165 columns]

# %%
#recuperando o nome das Unidades da Federação:
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação") #inserir na posição 0
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  'Total']

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
#Definindo o index:
usaveis = usaveis.set_index('Unidade da Federação')
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660122027.15
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614919044.63
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8581189975.91
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236415402.51
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215853015.00
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791541570.52
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418737536.66
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405850698.58
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337389922.09
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41396408548.81
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681514706.67
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7835011163.40
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764391179.92
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324525096.33
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180119781.15
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973572261.43
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592422853.56
#
# [27 rows x 165 columns]

# %%
#Ordenando as colunas de Unidade da Federação pelo valor 'Total' e excluindo a coluna 'Total' em seguida:
ordenado_por_total = usaveis.sort_values('Total', ascending=False)
ordenado_por_total = ordenado_por_total.drop('Total', axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 41 Paraná             554800.22 1431708.01  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
#
# [5 rows x 164 columns]

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]
ordenado_por_total
# Out:
#                            2008/Fev     2008/Mar  ...     2021/Fev     2021/Mar
# Unidade da Federação                              ...
# 35 São Paulo           172961999.58 170556696.16  ... 268193064.06 177408317.71
# 31 Minas Gerais         70301089.50  79119005.51  ... 119877417.15  79780838.00
# 41 Paraná               48855046.46  55611791.07  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul    45897704.82  52928695.92  ...  84404640.00  37798832.80
# 33 Rio de Janeiro       44128159.73  42900847.02  ...  60873103.08  49149884.48
# 29 Bahia                33410124.06  41316672.72  ...  55544579.04  31314602.44
# 26 Pernambuco           26222079.10  30716361.81  ...  62259409.32  39472738.81
# 42 Santa Catarina       24409572.92  27483480.50  ...  47429335.91  19375822.56
# 23 Ceará                27643304.86  30085370.22  ...  30186951.00  17173151.55
# 52 Goiás                18149374.27  20992213.03  ...  32253788.65  24867001.02
# 15 Pará                 20126081.01  22149375.82  ...  23343222.94  13069564.31
# 21 Maranhão             13452263.93  14750895.33  ...  23260245.95  17294509.11
# 32 Espírito Santo       10032886.43  12262049.08  ...  25669612.63  15606368.11
# 24 Rio Grande do Norte   9110108.87  10126626.54  ...  18186942.80   8733455.36
# 25 Paraíba              10871589.62  12348758.14  ...  16996494.03  12517894.05
# 53 Distrito Federal     10215956.80  11627918.26  ...  19004029.87  14731938.43
# 50 Mato Grosso do Sul    8279288.79   9793888.78  ...  11428462.42   4035989.77
# 22 Piauí                 9711680.20  10428191.09  ...  13636005.36   9542151.53
# 27 Alagoas               8112220.30   9210505.56  ...  12792571.64   8180887.21
# 51 Mato Grosso           7929894.93   9416367.68  ...  13207979.82   8835890.09
# 13 Amazonas              7934652.10   8641517.13  ...  13679358.06   6799060.80
# 28 Sergipe               4636850.76   5017838.07  ...   4129845.36   3081081.42
# 17 Tocantins             5051932.07   5200151.87  ...    416534.32    928756.84
# 11 Rondônia              1940792.63   1955721.68  ...   6039419.59   4732441.04
# 12 Acre                  1743978.66   2057439.02  ...   2272733.90   1137341.65
# 14 Roraima                771687.83    876091.18  ...   3044798.77   2381844.31
# 16 Amapá                 1275063.72   1177745.93  ...   1534733.18    989155.40
#
# [27 rows x 158 columns]

# %% [markdown]
# Retirando os números que antecedem os nomes das Unidades da Federação:

# %%
ordenado_por_total.index = ordenado_por_total.index.str[3:]

# %%
ordenado_por_total = ordenado_por_total/1000000

# %%
ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  ...  2021/Fev  2021/Mar
# Unidade da Federação                      ...
# São Paulo               172.96    170.56  ...    268.19    177.41
# Minas Gerais             70.30     79.12  ...    119.88     79.78
# Paraná                   48.86     55.61  ...     83.13     43.48
# Rio Grande do Sul        45.90     52.93  ...     84.40     37.80
# Rio de Janeiro           44.13     42.90  ...     60.87     49.15
#
# [5 rows x 158 columns]

# %% [markdown]
# Guardando o dataframe transposto na variável mensal:

# %%
mensal = ordenado_por_total.T
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008/Fev                 172.96         70.30   48.86  ...  1.74     0.77   1.28
# 2008/Mar                 170.56         79.12   55.61  ...  2.06     0.88   1.18
# 2008/Abr                 170.34         79.05   56.12  ...  2.06     0.90   1.40
# 2008/Mai                 172.46         79.27   55.57  ...  2.23     1.03   1.41
# 2008/Jun                 175.49         79.62   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %% [markdown]
# Trabalhando com formatação de dia:

# %%
from datetime import date

meses = { 
    'Jan' : 1,
    'Fev' : 2,
    'Mar' : 3,
    'Abr' : 4,
    'Mai' : 5,
    'Jun' : 6,
    'Jul' : 7,
    'Ago' : 8,
    'Set' : 9,
    'Out' : 10,
    'Nov' : 11,
    'Dez' : 12,
} #dicionário com os meses e seus números correspondentes, para fazer a substituição

def para_dia(ano_mes):
    ano: int = int(ano_mes[:4]) 
    mes: str = ano_mes[5:]
    mes_numero: int = meses[mes] #usando o dicionário para definir os meses
    return date(ano, mes_numero, 1)

# %%
mensal.index = mensal.index.map(para_dia)
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  ...  Acre  Roraima  Amapá
# 2008-02-01               172.96         70.30   48.86  ...  1.74     0.77   1.28
# 2008-03-01               170.56         79.12   55.61  ...  2.06     0.88   1.18
# 2008-04-01               170.34         79.05   56.12  ...  2.06     0.90   1.40
# 2008-05-01               172.46         79.27   55.57  ...  2.23     1.03   1.41
# 2008-06-01               175.49         79.62   56.09  ...  2.11     0.94   1.42
#
# [5 rows x 27 columns]

# %%
mensal.index
# Out:
# Index([2008-02-01, 2008-03-01, 2008-04-01, 2008-05-01, 2008-06-01, 2008-07-01,
#        2008-08-01, 2008-09-01, 2008-10-01, 2008-11-01,
#        ...
#        2020-06-01, 2020-07-01, 2020-08-01, 2020-09-01, 2020-10-01, 2020-11-01,
#        2020-12-01, 2021-01-01, 2021-02-01, 2021-03-01],
#       dtype='object', length=158)

# %% [markdown]
# Agora temos todas as datas alteradas! vamos plotar um novo gráfico para ver como isso vai melhorar a visualização:

# %%
plt.figure(figsize=(10, 6))
ax = sns.lineplot(data=mensal, x=mensal.index, y='São Paulo')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Agora automaticamente foram colocados os anos 2008, 2010, 2012, 2014, 2016, 2018 e 2020, melhorando a visualização e deixando a legenda mais limpa.
# Adicionando mais um estado ao gráfico:

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal, x=mensal.index, y='São Paulo')
ax = sns.lineplot(data=mensal, x=mensal.index, y='Minas Gerais')
plt.xticks(rotation=30)
plt.grid(linestyle="--")
plt.ylim(0, 400)
plt.show()

# %% [markdown]
# Nós chamamos o lineplot duas vezes: São Paulo e Minas Gerais. Você só não sabe qual é qual, esse é o primeiro problema. Se você não customizar o nome do eixo, você também não sabe.
# O problema é o seguinte: o seaborn recebe um `x` e um `y`. O `x` é o índice e o `y` são os estados, não tem problema. Mas o problema é: eu só posso ter um único `x`.

# %% [markdown]
# Outra forma que eu poderia representar essa tabela com todos esses dados:
#
# Primeiro, vamos tirar esse índice, `mensal.reset_index()`:

# %%
mensal.reset_index()
# Out:
# Unidade da Federação       index  São Paulo  Minas Gerais  ...  Acre  Roraima  Amapá
# 0                     2008-02-01     172.96         70.30  ...  1.74     0.77   1.28
# 1                     2008-03-01     170.56         79.12  ...  2.06     0.88   1.18
# 2                     2008-04-01     170.34         79.05  ...  2.06     0.90   1.40
# 3                     2008-05-01     172.46         79.27  ...  2.23     1.03   1.41
# 4                     2008-06-01     175.49         79.62  ...  2.11     0.94   1.42
# ..                           ...        ...           ...  ...   ...      ...    ...
# 153                   2020-11-01     324.60        168.56  ...  3.39     3.53   2.71
# 154                   2020-12-01     326.85        166.38  ...  3.71     3.13   2.83
# 155                   2021-01-01     324.12        155.06  ...  3.01     3.21   2.51
# 156                   2021-02-01     268.19        119.88  ...  2.27     3.04   1.53
# 157                   2021-03-01     177.41         79.78  ...  1.14     2.38   0.99
#
# [158 rows x 28 columns]

# %% [markdown]
# Agora o que eu vamos fazer é o seguinte: alterar nossa tabela para pegar essas várias variáveis, que são São Paulo, Minas Gerais, Paraná, Rio Grande do Sul etc., e transformá-las em linhas extras. Se antes eu tinha uma única linha, agora eu vou ter 27 linhas para cada um desses.
#
# O que eu tenho que falar é que eu quero derreter a minha tela, eu quero pegá-la e quebrá-la para baixo. Isso é feito com `melt()` e quando você faz um melt, você tem que falar qual é a coluna que você não quer derreter, que você quer manter do jeito que está. Vamos pensar? A coluna VALOR nem existe, a coluna ESTADO' também não existe, só existe a coluna MES, que se chama index, então `id_vars` é quem identifica, as colunas que identificam unicamente alguma coisa é só `index`:

# %%
mensal.reset_index().melt(id_vars=['index'])
# Out:
#            index Unidade da Federação  value
# 0     2008-02-01            São Paulo 172.96
# 1     2008-03-01            São Paulo 170.56
# 2     2008-04-01            São Paulo 170.34
# 3     2008-05-01            São Paulo 172.46
# 4     2008-06-01            São Paulo 175.49
# ...          ...                  ...    ...
# 4261  2020-11-01                Amapá   2.71
# 4262  2020-12-01                Amapá   2.83
# 4263  2021-01-01                Amapá   2.51
# 4264  2021-02-01                Amapá   1.53
# 4265  2021-03-01                Amapá   0.99
#
# [4266 rows x 3 columns]

# %% [markdown]
# Para garantir a ordem dessas colunas, deixar de forma explícita, vamos falar que as variáveis de valor são todas essas, São Paulo até o último estado, são os estados. Então `mensal.columns`, todos os estados. Assim eu tenho certeza que vem nessa ordem, eu estou forçando uma ordem:

# %%
mensal.reset_index().melt(id_vars=["index"], value_vars=mensal.columns)
# Out:
#            index Unidade da Federação  value
# 0     2008-02-01            São Paulo 172.96
# 1     2008-03-01            São Paulo 170.56
# 2     2008-04-01            São Paulo 170.34
# 3     2008-05-01            São Paulo 172.46
# 4     2008-06-01            São Paulo 175.49
# ...          ...                  ...    ...
# 4261  2020-11-01                Amapá   2.71
# 4262  2020-12-01                Amapá   2.83
# 4263  2021-01-01                Amapá   2.51
# 4264  2021-02-01                Amapá   1.53
# 4265  2021-03-01                Amapá   0.99
#
# [4266 rows x 3 columns]

# %% [markdown]
# Agora vamos definir o nome das colunas:

# %%
mensal_aberto = mensal.reset_index().melt(id_vars=['index'], value_vars=mensal.columns)
mensal_aberto.columns = ['dia_mes_ano', 'uf', 'gasto']
mensal_aberto['dia_mes_ano'] = mensal_aberto['dia_mes_ano'].astype('datetime64')
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto
# 0  2008-02-01  São Paulo 172.96
# 1  2008-03-01  São Paulo 170.56
# 2  2008-04-01  São Paulo 170.34
# 3  2008-05-01  São Paulo 172.46
# 4  2008-06-01  São Paulo 175.49

# %% [markdown]
# Visualização gráfica após o melt:

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto, x="dia_mes_ano", y="gasto")
plt.ylim(0, 400)
plt.xticks(rotation=30)
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
#  Nesse gráfico a linha azul representa o que podemos esperar que seja a média dos valores. Isso é, de todos os valores de 2008, esse é o valor médio e assim vai progressivamente. E essa faixa é um intervalo de confiança que eles criam estatisticamente. O plot agrega vários Y, quer dizer, para o mesmo valor de X, mesmo mês. Você tem vários Y, ele agrega. E ele mostra uma estimativa de tendência central, que no nosso caso é a média, e o intervalo de confiança para aquela estimativa.

# %% [markdown]
# Para incluir todos os estados no gráfico: Uma forma é definir a tonalidade, o `hue`. O `hue` vai ser a coluna “uf” e temos agora 27 linhas diferentes. Temos todos os estados sendo plotados agora:

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto, x="dia_mes_ano", y="gasto", hue="uf")
plt.xticks(rotation=30)
plt.grid(linestyle="--")
plt.ylim(0, 400)
plt.show()

# %%
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto
# 0  2008-02-01  São Paulo 172.96
# 1  2008-03-01  São Paulo 170.56
# 2  2008-04-01  São Paulo 170.34
# 3  2008-05-01  São Paulo 172.46
# 4  2008-06-01  São Paulo 175.49

# %% [markdown]
# Para fazer comparação entre os anos, precisamos alterar o formato do dia_mes_ano em mensal_aberto, adicionado a linha em negrito com `.astype('datetime64')`:
#
#
# `mensal_aberto = mensal.reset_index().melt(id_vars=['index'], value_vars=mensal.columns)`
#
# `mensal_aberto.columns = ['dia_mes_ano', 'uf', 'gasto']`
#
# **`mensal_aberto['dia_mes_ano'] = mensal_aberto['dia_mes_ano'].astype('datetime64')`**
#
# `mensal_aberto.head()`

# %%
mensal_aberto["mes"] = mensal_aberto["dia_mes_ano"].dt.month
mensal_aberto["ano"] = mensal_aberto["dia_mes_ano"].dt.year
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano
# 0  2008-02-01  São Paulo 172.96    2  2008
# 1  2008-03-01  São Paulo 170.56    3  2008
# 2  2008-04-01  São Paulo 170.34    4  2008
# 3  2008-05-01  São Paulo 172.46    5  2008
# 4  2008-06-01  São Paulo 175.49    6  2008

# %% [markdown]
# Visualização gráfica:

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto, x="mes", y="gasto", hue="ano")
plt.xticks(rotation=360)
plt.grid(linestyle="--")
plt.ylim(0, 400)
plt.show()

# %% [markdown]
# Para ter uma análise possível de interpretar, vamos começar fazendo somente um estado:

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"), x="mes", y="gasto", hue="ano")
plt.xticks(rotation=360)
plt.grid(linestyle="--")
plt.ylim(0, 400)
plt.show()

# %% [markdown]
# Esse gráfico conta a história do que acontece em cada mês.

# %% [markdown]
# E se quisermos dividir pelo número de dias daquele mês?
# podemos criar um dicionário para isso:

# %%
dias_por_mes = {
    1 : 31,
    2 : 28,
    3 : 31,
    4 : 30,
    5 : 31,
    6 : 30,
    7 : 31,
    8 : 31,
    9 : 30,
    10 : 31,
    11 : 30,
    12 : 31
}

# %% [markdown]
# o `.map()` funciona não só para uma função, funciona para um dicionário:

# %%
mensal_aberto['mes'].map(dias_por_mes)
# Out:
# 0       28
# 1       31
# 2       30
# 3       31
# 4       30
#         ..
# 4261    30
# 4262    31
# 4263    31
# 4264    28
# 4265    31
# Name: mes, Length: 4266, dtype: int64

# %% [markdown]
# E temos esses valores de quantos milhões gastos por dia por mês. Esse daqui seria o `mensal_aberto[‘diario’]`, seria o gasto diário em milhões. Então `mensal_aberto.head()`, só para vermos. Temos esses valores.

# %%
mensal_aberto['gasto'] / mensal_aberto['mes'].map(dias_por_mes)
# Out:
# 0      6.18
# 1      5.50
# 2      5.68
# 3      5.56
# 4      5.85
#        ...
# 4261   0.09
# 4262   0.09
# 4263   0.08
# 4264   0.05
# 4265   0.03
# Length: 4266, dtype: float64

# %%
mensal_aberto['gasto_diario'] = mensal_aberto['gasto'] / mensal_aberto['mes'].map(dias_por_mes)
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.96    2  2008          6.18
# 1  2008-03-01  São Paulo 170.56    3  2008          5.50
# 2  2008-04-01  São Paulo 170.34    4  2008          5.68
# 3  2008-05-01  São Paulo 172.46    5  2008          5.56
# 4  2008-06-01  São Paulo 175.49    6  2008          5.85

# %% [markdown]
# Agrupamento dos Estados por ano:

# %%
estado_a_analisar = mensal_aberto.query("uf=='São Paulo'")
estado_a_analisar.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.96  Fev  2008          6.18
# 1  2008-03-01  São Paulo 170.56  Mar  2008          5.50
# 2  2008-04-01  São Paulo 170.34  Abr  2008          5.68
# 3  2008-05-01  São Paulo 172.46  Mai  2008          5.56
# 4  2008-06-01  São Paulo 175.49  Jun  2008          5.85

# %%
gastos_por_ano = estado_a_analisar.groupby("ano").sum()
gastos_por_ano
# Out:
#        gasto  gasto_diario
# ano
# 2008 1961.42         64.64
# 2009 2489.87         81.85
# 2010 2698.63         88.69
# 2011 2795.61         91.94
# 2012 2875.72         94.52
# 2013 3065.13        100.75
# 2014 3202.64        105.32
# 2015 3189.50        104.85
# 2016 3202.24        105.31
# 2017 3304.06        108.59
# 2018 3383.68        111.24
# 2019 3495.64        114.93
# 2020 3782.23        124.29
# 2021  769.72         25.76

# %% [markdown]
# Gráficos dos gastos de São Paulo por ano:

# %%
sns.scatterplot(data=gastos_por_ano, x=gastos_por_ano.index, y='gasto')

# %%
sns.lineplot(data=gastos_por_ano, x=gastos_por_ano.index, y='gasto')

# %%
sns.barplot(data=gastos_por_ano, x=gastos_por_ano.index, y='gasto', palette=sns.color_palette("rocket_r", 13))

# %% [markdown]
# Podemos escolher somente alguns estados, por exemplo, “São Paulo", “Minas Gerais" e "Pernambuco" e fazer um `groupby `:

# %%
estados = ["São Paulo", "Minas Gerais", "Pernambuco"]
por_ano_dos_estados = mensal_aberto.query("uf in @estados").groupby(["uf","ano"]).sum().reset_index() # índice não é coluna, por isso dar um reset index
por_ano_dos_estados.head()
# Out:
#              uf   ano   gasto  gasto_diario
# 0  Minas Gerais  2008  894.38         29.44
# 1  Minas Gerais  2009 1149.17         37.77
# 2  Minas Gerais  2010 1217.52         40.03
# 3  Minas Gerais  2011 1315.08         43.24
# 4  Minas Gerais  2012 1408.44         46.29

# %% [markdown]
# Visualização gráfica:

# %%
sns.barplot(data=por_ano_dos_estados, x="ano", y="gasto")

# %% [markdown]
#  Esse gráfico não é o ideal, pois foram geradas barras que representam os intervalos de confiança, pois para o mesmo ano temos três valores: São Paulo, Minas Gerais, Pernambuco. O objetivo era poder comparar os três estados:

# %%
sns.barplot(data=por_ano_dos_estados, x="ano", y="gasto", hue="uf")

# %% [markdown]
# Agora é possível ter uma comparação, mas são muitas coisas acontecendo ao mesmo tempo no gráfico. Vamos tentar um gráfico de linhas:

# %%
sns.lineplot(data=por_ano_dos_estados, x="ano", y="gasto", hue="uf")

# %% [markdown]
# Agora a visualização melhorou, mas vamos tentar um catplot:

# %%
sns.catplot(data=por_ano_dos_estados, y="gasto", x="ano", kind="bar", col="uf")

# %% [markdown]
# Se colocarmos 'uf' como row, dá para analisar os gráficos posicionados na vertical:

# %%
sns.catplot(data=por_ano_dos_estados, y="gasto", x="ano", kind="bar", row="uf")

# %% [markdown]
# ###**Desafio 01: Reordenar as cores pelo valor do eixo y.**

# %%
sns.barplot(data=gastos_por_ano, x=gastos_por_ano.index, y='gasto', palette=sns.color_palette("rocket_r", 13))

# %% [markdown]
# ###**Desafio 02: Explorar a documentação do Seaborn.**

# %% [markdown]
# [Documentação do Seaborn](https://seaborn.pydata.org/introduction.html)

# %% [markdown]
# ###**Desafio 03: Pensar e elaborar novos gráficos depois de estudar o Seaborn, compartilhar com uma breve descrição no Discord, para que outros colegas aprendam sobre o gráfico usado.**

# %% [markdown]
# [Tipos de gráficos do Seaborn](https://seaborn.pydata.org/examples/index.html)
